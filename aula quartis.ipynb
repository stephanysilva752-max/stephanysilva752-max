# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('pesquisa_satisfacao.csv', sep = ';')
df
#para conferir se está correto verificar as 5 primeiras linhas ( df.head(5) )
#display(df)
#print(df)

# %%
#formula do groupby para poder visualizar colunas especificas
media_satisfacao = df.groupby('Satisfação')['Tempo de Espera (min)'].mean().reset_index()
media_satisfacao['Tempo de Espera (min)'] = round(media_satisfacao['Tempo de Espera (min)'],2)
media_satisfacao

# %%
df_anp = pd.read_csv('ANP2025.csv', sep = ';' )
df_anp

# %%
#identificando apenas as 5 primeiras colunas onde aparece rj - loc serve como filtro
df_anp_rj = df_anp.loc[df_anp['Estado - Sigla'] == 'RJ']
df_anp_rj.head(5)

# %%
#substituindo a virgula pelo ponto - str é a formula string e para poder mudar é str.replace (replace - dizendo que vou troacr algo nessa string ) (nome da variavel mais a alteração que eu vou fazer)
df_anp_rj['Valor de Venda'] = df_anp_rj['Valor de Venda'].str.replace(',' , '.').astype(float)

# %%
media_munic_rj = df_anp_rj.groupby('Municipio')['Valor de Venda'].mean().reset_index()
media_munic_rj = media_munic_rj.sort_values(by='Valor de Venda', ascending=False)
media_munic_rj

# %%
array_valor_venda = np.array(media_munic_rj['Valor de Venda'])

# %%
media = np.mean(array_valor_venda)
mediana = np.median(array_valor_venda)
q1 = np.quantile(array_valor_venda, 0.25)
q2 = np.quantile(array_valor_venda, 0.50)
q3 = np.quantile(array_valor_venda, 0.75)

print(f'A média é {media}')
print(f'A mediana é {mediana}')
print(f'Primeiro quartil (Q1): {q1}')
print(f'Segundo quartil (Q2, Mediana): {q2}')
print(f'Terceiro quartil (Q3): {q3}')

# %%
munic_acima_q3 = media_munic_rj.loc[media_munic_rj['Valor de Venda'] > q3]
munic_acima_q3

# %%
#formula do groupby para poder visualizar colunas especificas
media_satisfacao = df.groupby('Satisfação')['Tempo de Espera (min)'].mean().reset_index()
media_satisfacao['Tempo de Espera (min)'] = round(media_satisfacao['Tempo de Espera (min)'],2)
media_satisfacao

# %%
df_rj_etanol = df_anp.loc[(df_anp['Municipio'] == 'RIO DE JANEIRO') & (df_anp['Produto'] == 'ETANOL')]
df_rj_etanol

# %%
#substituindo a virgula pelo ponto - str é a formula string e para poder mudar é str.replace (replace - dizendo que vou troacr algo nessa string ) (nome da variavel mais a alteração que eu vou fazer)
df_rj_etanol['Valor de Venda'] = df_rj_etanol['Valor de Venda'].str.replace(',' , '.').astype(float)

# %%
bairro_etanol = df_rj_etanol.groupby('Bairro')['Valor de Venda'].mean().reset_index()
bairro_etanol = bairro_etanol.sort_values(by='Valor de Venda', ascending=False)
bairro_etanol

# %%
q3=df_rj_etanol['Valor de Venda'].quantile(0.75)
bairro_etanol=df_rj_etanol[df_rj_etanol['Valor de Venda']>= q3]
bairro_etanol.sort_values(by='Valor de Venda', ascending=False)
bairro_etanol

# %%
###EXERCICIO - FURTO DE CELULAR - FILTRAR OS DADOS REFERENTE A FURTO DE CELULAR

# %%
df = pd.read_csv('https://www.ispdados.rj.gov.br/Arquivos/BaseDPEvolucaoMensalCisp.csv', sep= ';', encoding= 'latin1')

# %%
df_roubo_celular_dp = df.groupby('munic')['roubo_celular'].mean().reset_index()
df_roubo_celular_dp = df_roubo_celular_dp.sort_values(by='roubo_celular', ascending= False)
df_roubo_celular_dp
# Out:
#                       munic  roubo_celular
# 81     SÃ£o JoÃ£o de Meriti      38.032847
# 6              Belford Roxo      25.514599
# 50             Nova IguaÃ§u      23.274939
# 47               NilÃ³polis      20.675182
# 23          Duque de Caxias      18.880474
# ..                      ...            ...
# 35          Laje do MuriaÃ©       0.007299
# 22              Duas Barras       0.003650
# 83  SÃ£o SebastiÃ£o do Alto       0.003650
# 86        Trajano de Morais       0.003650
# 66           Rio das Flores       0.000000
#
# [90 rows x 2 columns]

# %%
df_roubo_celular_dp['roubo_celular'] = df_roubo_celular_dp['roubo_celular'].str.replace(',' , '.').astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[207], line 1
# ----> 1 df_roubo_celular_dp['roubo_celular'] = df_roubo_celular_dp['roubo_celular'].str.replace(',' , '.').astype(float)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:6321, in NDFrame.__getattr__(self, name)
#    6314 if (
#    6315     name not in self._internal_names_set
#    6316     and name not in self._metadata
#    6317     and name not in self._accessors
#    6318     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319 ):
#    6320     return self[name]
# -> 6321 return object.__getattribute__(self, name)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
# ...

# %%
array_furto_celular = np.array(df_roubo_celular_dp['roubo_celular'])

# %%
media  = np.mean(array_furto_celular)
mediana  = np.mean(array_furto_celular)
q1 = np.quantile(array_furto_celular, 0.25)
q2 = np.quantile(array_furto_celular, 0.50)
q3 = np.quantile(array_furto_celular, 0.75)
distancia = ( media - mediana ) / mediana

print(f'A média é {media}')
print(f'A mediana é {mediana}')
print(f'Primeiro quartil (Q1): {q1}')
print(f'Segundo quartil (Q2), Mediana: {q2}')
print(f'Primeiro quartil (Q3): {q3}')
print(f'A distancia entre a media e a mediana é de {distancia}')
# Out:
# A média é 3.2473421844732178
# A mediana é 3.2473421844732178
# Primeiro quartil (Q1): 0.06275422076112999
# Segundo quartil (Q2), Mediana: 0.36496350364963503
# Primeiro quartil (Q3): 2.89507299270073
# A distancia entre a media e a mediana é de 0.0

# %%
q1 = df_roubo_celular_dp['roubo_celular'].quantile(0.25)
array_furto_celular=df_roubo_celular_dp[df_roubo_celular_dp['roubo_celular']& df_roubo_celular_dp['munic']]
array_furto_celular.sort_values(by='roubo_celular', ascending=False) 
array_furto_celular
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\ops\array_ops.py:362, in na_logical_op(x, y, op)
#     353 try:
#     354     # For exposition, write:
#     355     #  yarr = isinstance(y, np.ndarray)
#    (...)    360     # Then Cases where this goes through without raising include:
#     361     #  (xint or xbool) and (yint or bool)
# --> 362     result = op(x, y)
#     363 except TypeError:
#
# TypeError: unsupported operand type(s) for &: 'float' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[206], line 2
#       1 q1 = df_roubo_celular_dp['roubo_celular'].quantile(0.25)
# ...

# %%
###Furtos de Celular no ano de 2024 nas cidades da região metropolitana do Estado.Seu trabalho é avaliar qual a melhor medida de tendência central para avaliar este tipo de ocorrência neste período de tempo.
